# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_ball = pd.read_html("https://tw.sports.yahoo.com/mlb/teams/%E6%B4%8B%E5%9F%BA/stats/")

# %%
df_ball[0]
# Out:
#                    球員    G   AB    R    H  2B  3B  HR  RBI  BB    K  SB  CS  \
# 0         DJ LeMahieu  145  602  109  197  33   2  26  102  46   90   5   2
# 1         Gio Urshela  132  442   73  139  34   0  21   74  25   87   1   1
# 2   Giancarlo Stanton   18   59    8   17   3   0   3   13  12   24   0   0
# 3      Cameron Maybin   82  239   48   68  17   0  11   32  30   72   9   6
# 4       Austin Romine   72  228   29   64  12   0   8   35  10   50   1   1
# 5      Gleyber Torres  144  546   96  152  26   0  38   90  48  129   5   2
# 6       Mike Tauchman   87  260   46   72  18   1  13   47  34   71   6   0
# 7         Aaron Judge  102  378   75  103  18   1  27   55  64  141   3   2
# 8       Clint Frazier   69  225   31   60  14   0  12   38  16   70   1   2
# 9           Luke Voit  118  429   72  113  21   1  21   62  71  142   0   0
# 10          Mike Ford   50  143   30   37   7   0  12   25  17   28   0   0
# ...

# %%
df=df_ball[0]

# %% [markdown]
# ### 去除掉投手後的打擊率排行

# %%
df.head(24)
# Out:
#                    球員    G   AB    R    H  2B  3B  HR  RBI  BB    K  SB  CS  \
# 0         DJ LeMahieu  145  602  109  197  33   2  26  102  46   90   5   2
# 1         Gio Urshela  132  442   73  139  34   0  21   74  25   87   1   1
# 2   Giancarlo Stanton   18   59    8   17   3   0   3   13  12   24   0   0
# 3      Cameron Maybin   82  239   48   68  17   0  11   32  30   72   9   6
# 4       Austin Romine   72  228   29   64  12   0   8   35  10   50   1   1
# 5      Gleyber Torres  144  546   96  152  26   0  38   90  48  129   5   2
# 6       Mike Tauchman   87  260   46   72  18   1  13   47  34   71   6   0
# 7         Aaron Judge  102  378   75  103  18   1  27   55  64  141   3   2
# 8       Clint Frazier   69  225   31   60  14   0  12   38  16   70   1   2
# 9           Luke Voit  118  429   72  113  21   1  21   62  71  142   0   0
# 10          Mike Ford   50  143   30   37   7   0  12   25  17   28   0   0
# ...

# %%
df.AVG.head(24)
# Out:
# 0     0.327
# 1     0.314
# 2     0.288
# 3     0.285
# 4     0.281
# 5     0.278
# 6     0.277
# 7     0.272
# 8     0.267
# 9     0.263
# 10    0.259
# 11    0.251
# 12    0.250
# 13    0.249
# 14    0.245
# 15    0.238
# 16    0.235
# 17    0.232
# 18    0.219
# 19    0.214
# 20    0.182
# 21    0.177
# 22    0.171
# 23    0.128
# Name: AVG, dtype: float64

# %%
a=df.AVG.head(24)

# %%
a.plot()

# %%
a.mean()
# Out:
# 0.24591666666666676
